# %% [markdown]
# # Kazan Data Science School

# %% [markdown]
# **Оглавление**:
#  - Что такое Data Science и зачем она нужна?
#  - Практическое применение
#     - Кейс Yandex и ММК (Снайпер)
#     - Кейс Prizma
#     - Кейс Нейронная оборона
#  - Основные понятия
#  - Процесс разработки
#  - Профессии
#  - Сообщество

# %% [markdown]
# ## Что такое Data Science и зачем она нужна?

# %% [markdown]
# **Data Science** (наука о данных) - это раздел информатики, изучающий проблемы анализа, обработки и визуализации данных.
#
# Наука о данных помогает принимать более эффективные решения, основывая их на данных из реального мира.
#
# Алгоритмы, обрабатывая большие объемы информации, адаптируют свои настройки и тем самым находят в них скрытые закономерности.

# %% [markdown]
# ## Практическое применение

# %% [markdown]
# ### Снайпер - боец Yandex и ММК
#
# <img align=center src="steel.jpg" width="800" />
#
# ММК - Магнитогорский металлургический комбинат. Производит черные металлы, в частности сталь. Когда сталь изготавливают, в расплавленном состоянии в нее добавляют специальные химические добавки, обеспечивающие стали нужную прочность.
#
# «Это как приправы в борще. Мы на эти добавки тратим около $300 млн в год. И очень хочется сэкономить», — рассказывает гендиректор ММК по финансам и экономике Сергей Сулимов.
#
# Металлурги передали «Яндексу» данные за 10 лет. Однако часть данных накапливалась с ошибками. Например, по некоторым из 10 000 плавок получалось, что на выходе из печи материала было в два раза меньше, чем загрузили. Такие данные отбрасывались.
#
# Первое время технология «Яндекса» будет работать в тестовом режиме: давать советы оператору, который вправе выбирать, прислушиваться к ним или нет. Если испытания пройдут успешно, определять расход ферросплавов начнут в автоматическом режиме, а оператор будет лишь присматривать за процессом на случай нештатных ситуаций.
#
# В результате применения модели экономия на добавках составляет около $5 млн в год, то есть 1,6%.
#
# Яркий пример применения Data Science в промышленности.
# <a href="https://www.youtube.com/watch?time_continue=358&v=w68Qe4flJ7Y">Более подробно в ролике.</a>

# %% [markdown]
# ### Prizma
#
# <div style="display: inline;">
# <img align=center src="prizma1.jpeg" width="500" style="white-space: nowrap; margin-right: 20px;" />
# <img align=center src="image2.jpeg" width="500" style="white-space: nowrap;" />
# </div>
# <br><br>
#
# **<a href="https://prisma-ai.com/">Prisma</a>** — технологическая компания, разрабатывающая алгоритмы в области Искусственного Интеллекта и Глубинного Обучения для обработки изображений.
#
# В июне 2016 году компания создала мобильное приложение Prisma, которое позволяет обрабатывать фотографии в стиле работ знаменитых художников. Менее чем за год приложение было скачано более 300 миллионов раз и было номинировано как лучшее приложение по версии App Store и Google Play.
#
# Компания создана Максимом Вороновым.
#
# В основе технологии лежат Сверточные нейронные сети. Это тип нейронных сетей, которые находят определенные шаблоны в данных, особенно в изображениях. Такие как линии, кривые, фигуры, а также сложные формы (глаза, нос, если обрабатывается изображение лица).
#
# <a href="https://habr.com/post/309508/">Статья на habr.</a>
#
# <a href="https://www.youtube.com/watch?v=52U4BG0ENiM">Видео на канале Андрея Созыкина.</a>

# %% [markdown]
# ### Нейронная оборона
#
# <img align="center" src="neuro_def.jpg" width="500"></img><br><br>
#
# Сотрудники «Яндекса» Алексей Тихонов и Иван Ямщиков выпустили альбом «Нейронная оборона», состоящий из песен и стихотворений, написанных нейронной сетью.
#
# Созданный ими алгоритм написал тексты в стиле Егора Летова, основателя группы «Гражданская оборона».
#
# <a href="https://habr.com/post/395503/">Статья на Habre.</a>
#
# <a href="https://music.yandex.ru/users/meduza.io/playlists/1016">Плейлист на Яндекс.Музыка</a>

# %% [markdown]
# ## Основные понятия
#
# Машинному обучению находят применение во многих сферах. А что же такое машинное обучение? Чтобы продолжить дальнейшее изучение темы, необходимо остановиться и разобраться в базовых вещах.
#
# **Artificial intelligence (AI)** - искусственный интеллект (ИИ). Наука и технология создания интеллектуальных машин, особенно интеллектуальных алгоритмов и компьютерных программ.
#
# **Machine learning (ML)** - машинное обучение (МЛ). Раздел искусственного интелекта (ИИ), объединяющий методы построения алгоритмов, которые адаптируются для решения конкретной задачи на основе исходного набора данных.
#
# **Data analysis** - анализ данных. Это процесс проверки, очистки, преобразования и моделирования данных с целью обнаружения полезной информации, обоснования выводов и поддержки принятия решений.

# %% [markdown]
# ## Процесс разработки
# Перед тем как появится готовое приложение, например предсказывающее счет футбольного матча, должны быть пройдены определенные этапы ее разработки.
#
# Даже когда привозят домой детали мебели, в коробку кладут инструкцию по сборке. Если Использовать инструкцию, то мебель будет собрана правильно и быстро, иначе вместо шкафа может получиться кровать, будет потрачено время и настроение будет не веселое. Также и в Data Science есть стандарты(инструкции) по созданию проектов.
#
# В 2000 году был представлен **CRISP_DM** - межотраслевой стандартный процесс для исследования данных.
#
# <img align="center" src="crispdm.jpg" width="500"></img>

# %% [markdown]
# Согласно CRISP-DM, проект проект состоит из шести основных этапов, выполняемых последовательно:
#  * Бизнес-анализ (Business understanding)
#  * Анализ данных (Data understanding)
#  * Подготовка данных (Data preparation)
#  * Моделирование (Modeling)
#  * Оценка результата (Evaluation)
#  * Внедрение (Deployment)
#
# **Значит:** полезно применять инструкции! <a href="https://habr.com/company/lanit/blog/328858/">Более подробно</a>

# %% [markdown]
# ## Профессии в Data Science
#
# Создание проекта состоит из нескольких этап и на каждом из них подключаются разные специалисты. У каждой из них свои особенности и инструменты, которые они применяют.
#
# В основном выделяют 4 профессий:
#  * **Специалист по организации данных** - продумывает какие данные будут хранится в базе, следит за тем чтобы данные были четкими и никуда не терялись. Использует базы данных Hadoop, PostgreSQL, Oracle.
#  * **Дата инженер** - он является связующим звеном между данными и всеми остальными специалистами, которым данные нужны. Он поднимает сервера для получения и обработки данных из базы, такие как Hadoop, Spark, Hive.
#  * **Бизнес аналитик** - человек-презентация. Он анализирует данные, находит в них интересную информацию и демонтрирует результаты людям, принимающим важные решения, в основном это директора. Использует дэшборды для получения данных, например Tableau, также использует сервисы, которые настроил Дата инженер.
#  * **Специалист по машинному обучению** - тот самый человек, который исследует данные, создает и обучает алгоритмы, работает с нейронными сетями. Использует в работе Python, библиотеки машинного обучения Scikit-learn, для нейронных сетей Keras и Tensorflow.

# %% [markdown]
# ## Сообщество
#
# <img align=center src="ods.jpg" width="400">
#
# Крупнейшее сообщество России по Data Science - <a href="http://ods.ai/">Open Data Science (ODS)</a>.
#
# Объединяет 12,500 человек, проводит более 30 ежегодных мероприятий, конференций. Самая масштабная конференция - Data Fest.
#
# Люди общаются в мессенджере <a href="http://slack.com/">Slack</a>, там есть группа ODS. Обсуждают новости из мира Data Science, делятся опытом, публикуют вакансии и просто весело беседуют.

# %% [markdown]
# ## Ai Community
#
# <img align=center src="ai_comm.png" width="400">
#
# Сообщество специалистов по Data Science и AI. Организуют мероприятия, митапы, хакатоны.
#
# http://ai-community.com/teams

# %% [markdown]
# # Добро пожаловать в Data Science!
